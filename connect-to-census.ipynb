# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
# %%R
# df <- read_csv('2023.csv')
# Out:
# Rows: 50296 Columns: 18
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (13): Common Name, Equipment Description, Executive Comment, Outage Cod...
# dbl   (1): Outage
# dttm  (4): Out of Service Date, Estimated Return to Service Date, Actual Ret...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
df = pd.read_excel('2023.xlsx')
df.to_csv('2023.csv', index=False)
pd.set_option('display.max_colwidth', None)
df.sample(10)
# Out:
#       Out of Service Date Common Name  Outage  \
# 27798 2023-07-19 02:08:00       ES229  897011
# 26662 2023-07-11 11:32:00       ES426  893695
# 41269 2023-10-26 07:48:00       ES118  936427
# 46240 2023-12-02 20:15:00       ES326  949759
# 45340 2023-11-26 01:03:00       ES302  947555
# 31367 2023-08-13 21:58:00       ES448  906913
# 35873 2023-09-15 12:58:00       EL309  919936
# 18362 2023-05-15 10:24:00       ES318  861899
# 4919  2023-02-07 08:48:00       ES452  806147
# 40867 2023-10-23 14:44:00       EL110  935225
#
#                                                Equipment Description  \
# 27798          ESC: ES229 - 227 - 34 St-Herald Sq - Bronx Bound Plat
# 26662      ESC: ES426 - 221 - 21 St-Queensbridge - Queens Bound Plat
# 41269                             ESC: ES118 - 146 - 181 St - Mezz B
# 46240  ESC: ES326 - 167 - W 4 St-Wash Sq - Upper Brooklyn Bound Plat
# 45340                    ESC: ES302 - 331 - Park Place - Island Plat
# 31367               ESC: ES448 - 456 - 61 St-Woodside - Outside Area
# 35873                           ELE: EL309 - 024 - Court St - Mezz A
# 18362            ESC: ES318 - 174 - Jay St-Metro Tech - Outside Area
# 4919            ESC: ES452 - 267 - Jackson Hts-Roosevest Av - Mezz A
# 40867                                      ELE: EL110 - 301 - 181 St
#
#                                                                           Executive Comment  \
# 27798                                                                                   NaN
# 26662                                                                                   NaN
# 41269  This escalator is out of service A&P for Kone Contractors to remove motor from ES117
# 46240                        This Escalator is out of service due to LIFTNET event: Ready\n
# 45340                                       This escalator is out for Liftnet Event: Ready.
# 31367                                                                                   NaN
# 35873                                                                                   NaN
# 18362                                                                                   NaN
# 4919                                                                                    NaN
# 40867                   This Elevator is out of service due to LIFTNET event: No Comm/Power
#
#       Outage Code     Status             External Source Note  \
# 27798         CLN     Closed                              NaN
# 26662          FR  Cancelled                      Not Running
# 41269         APC     Closed                              NaN
# 46240         BRP     Closed                            Ready
# 45340         VAN     Closed                            Ready
# 31367         ACC     Closed                            Ready
# 35873          FR  Cancelled                    No Comm/Power
# 18362         POW     Closed  Stop Distance < Minimum Allowed
# 4919          MRP     Closed                              NaN
# 40867         VAN     Closed                    No Comm/Power
#
#       Reason Shown to Public Reason Shown to Public Description  \
# 27798            MAINTENANCE                        Maintenance
# 26662           UNDERINVESTG                Under Investigation
# 41269            PLANNEDWORK                       Planned Work
# 46240                 REPAIR                             Repair
# 45340                 REPAIR                             Repair
# 31367                 REPAIR                             Repair
# 35873           UNDERINVESTG                Under Investigation
# 18362           UNDERINVESTG                Under Investigation
# 4919             PLANNEDWORK                       Planned Work
# 40867                 REPAIR                             Repair
#
#       Estimated Return to Service Date Actual Return to Service Date  \
# 27798              2023-07-19 08:08:00           2023-07-19 02:28:00
# 26662              2023-07-11 20:00:00                           NaT
# 41269              2023-10-26 12:00:00           2023-10-26 09:55:00
# 46240              2023-12-03 05:00:00           2023-12-02 21:00:00
# 45340              2023-11-26 10:00:00           2023-11-26 02:00:00
# 31367              2023-08-14 06:00:00           2023-08-14 00:40:00
# 35873              2023-09-15 21:00:00                           NaT
# 18362              2023-05-15 19:00:00           2023-05-15 11:25:00
# 4919               2023-02-07 17:00:00           2023-02-07 13:05:00
# 40867              2023-10-23 23:00:00           2023-10-23 16:00:00
#
#                  Reference                      Source Service Code  \
# 27798                  NaN                       Phone    EE-MANOUT
# 26662  ST230711.txt - 1876  External Monitoring System     EE-LNOUT
# 41269                  NaN                       Phone    EE-MANOUT
# 46240   ST231202.txt - 984  External Monitoring System     EE-LNOUT
# 45340   ST231126.txt - 142  External Monitoring System     EE-LNOUT
# 31367  ST230813.txt - 3501  External Monitoring System     EE-LNOUT
# 35873  ST230915.txt - 2813  External Monitoring System     EE-LNOUT
# 18362  ST230515.txt - 1373  External Monitoring System     EE-LNOUT
# 4919                   NaN                       Phone    EE-MANOUT
# 40867  ST231023.txt - 1858  External Monitoring System     EE-LNOUT
#
#              Date Created Status Code  \
# 27798 2023-07-19 02:09:00          CL
# 26662 2023-07-11 11:51:00           C
# 41269 2023-10-26 07:48:00          CL
# 46240 2023-12-02 20:21:00          CL
# 45340 2023-11-26 01:17:00          CL
# 31367 2023-08-13 22:13:00          CL
# 35873 2023-09-15 13:18:00           C
# 18362 2023-05-15 10:33:00          CL
# 4919  2023-02-07 08:49:00          CL
# 40867 2023-10-23 15:00:00          CL
#
#                                                                                                                                                                                          Outage Comments
# 27798  ***This escalator is out of service due to Station cleaning it***\n\nCTA Chapman #145132 -  take this escalator out of service to clean it\n CTA Chapman #145132 reports complete cleaning RTS.
# 26662                                                                                                                                                        \n\nAs per Galaxy Client escalator running
# 41269                               E&EH Perez report OOS @ 07:48 A&P for Kone Contractors to remove motor from ES117. E&EM Dominguez reported A&P completed. Motor was removed by KONE. RTS @0955 hrs.
# 46240                                                                                                                                                                                                NaN
# 45340                                                                                                                                                                                                NaN
# 31367                                                                                                                                                                                                NaN
# 35873                                                                                                                                                                  New server shows machine running
# 18362                                                                                                                                                                                                NaN
# 4919                                                                                                                                                                                                 NaN
# 40867                                                                                                                                                                                                NaN

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
# filter down to elevators only
df_ele = df[df['Equipment Description'].str.startswith('ELE')]
df_ele.sample(10)
# Out:
#       Out of Service Date Common Name  Outage  \
# 2279  2023-01-18 00:40:00       EL719  797754
# 28051 2023-07-20 11:17:00       EL403  897711
# 32192 2023-08-19 23:19:00       EL215  909333
# 23075 2023-06-16 09:57:00       EL279  883949
# 19294 2023-05-21 06:38:00       EL371  872723
# 10502 2023-03-21 15:07:00       EL367  822486
# 48981 2023-12-21 09:35:00       EL342  958345
# 1526  2023-01-12 09:41:00       EL235  795611
# 19796 2023-05-24 09:00:00       EL772  874930
# 34057 2023-09-03 02:00:00       EL756  914605
#
#                                                         Equipment Description  \
# 2279                                ELE: EL719 - 106 - Fulton St - Upper Plat
# 28051               ELE: EL403 - 222 - Roosevelt Island - Brooklyn Bound Plat
# 32192                     ELE: EL215 - 318 - 34 St-Penn Station - Island Plat
# 23075             ELE: EL279 - 161 - 59 St-Columbus Circle - Bronx Bound Plat
# 19294                     ELE: EL371 - 026 - Dekalb Av - Manhattan Bound Plat
# 10502                 ELE: EL367 - 955 - COZINE IRONSHOP - PASSENGER ELEVATOR
# 48981                     ELE: EL342 - 188 - Euclid Av - Manhattan Bound Plat
# 1526          ELE: EL235 - 225 -47-50 Sts-Rockefeller Ctr - Queens Bound Plat
# 19796                         ELE: EL772 - 135 - Livonia Av - Manhattan Bound
# 34057  ELE: EL756 - 341 - Eastern Pkwy-Brooklyn Museum - Manhattan Bound Plat
#
#                                                                          Executive Comment  \
# 2279                                                                                   NaN
# 28051                                                                                  NaN
# 32192                                                                                  NaN
# 23075                                                                                  NaN
# 19294                                                                                  NaN
# 10502                                                                                  NaN
# 48981  This unit was removed from service by E&E personnel to provide A&P for Contractors.
# 1526                                                                                   NaN
# 19796                                                                                  NaN
# 34057                                                                                  NaN
#
#       Outage Code     Status                      External Source Note  \
# 2279           PM     Closed                                       NaN
# 28051          FR  Cancelled                      Main Line Disconnect
# 32192         VAN     Closed  Door Opening/ F. Door Open Limit failure
# 23075         MRP     Closed                                       NaN
# 19294          FR     Closed                                       NaN
# 10502         BRP     Closed                                       NaN
# 48981         APC     Closed                                       NaN
# 1526          MRP     Closed                                       NaN
# 19796          PM     Closed                                       NaN
# 34057         UNI  Cancelled                 Low Pressure Switch (LPS)
#
#       Reason Shown to Public Reason Shown to Public Description  \
# 2279             MAINTENANCE                        Maintenance
# 28051           UNDERINVESTG                Under Investigation
# 32192                 REPAIR                             Repair
# 23075            PLANNEDWORK                       Planned Work
# 19294           UNDERINVESTG                Under Investigation
# 10502                 REPAIR                             Repair
# 48981            PLANNEDWORK                       Planned Work
# 1526             PLANNEDWORK                       Planned Work
# 19796            MAINTENANCE                        Maintenance
# 34057           UNDERINVESTG                Under Investigation
#
#       Estimated Return to Service Date Actual Return to Service Date  \
# 2279               2023-01-18 08:40:00           2023-01-18 05:30:00
# 28051              2023-07-20 20:00:00                           NaT
# 32192              2023-08-20 08:00:00           2023-08-20 00:35:00
# 23075              2023-06-16 17:00:00           2023-06-16 11:00:00
# 19294              2023-05-21 15:38:00           2023-05-21 11:40:00
# 10502              2023-03-23 23:08:00           2023-03-22 12:30:00
# 48981              2023-12-21 15:00:00           2023-12-21 10:25:00
# 1526               2023-01-12 16:00:00           2023-01-12 13:15:00
# 19796              2023-05-24 18:00:00           2023-05-24 12:00:00
# 34057              2023-09-03 11:00:00                           NaT
#
#                  Reference                      Source Service Code  \
# 2279                   NaN                       Phone    EE-MANOUT
# 28051  ST230720.txt - 2598  External Monitoring System     EE-LNOUT
# 32192  ST230819.txt - 2479  External Monitoring System     EE-LNOUT
# 23075                  NaN                       Phone    EE-MANOUT
# 19294                  NaN                       Phone    EE-MANOUT
# 10502                  NaN                       Phone    EE-MANOUT
# 48981                  NaN                       Phone    EE-MANOUT
# 1526                   NaN                       Phone    EE-MANOUT
# 19796                  NaN                       Phone    EE-MANOUT
# 34057   ST230903.txt - 212  External Monitoring System     EE-LNOUT
#
#              Date Created Status Code  \
# 2279  2023-01-18 00:40:00          CL
# 28051 2023-07-20 11:34:00           C
# 32192 2023-08-19 23:30:00          CL
# 23075 2023-06-16 09:58:00          CL
# 19294 2023-05-21 06:39:00          CL
# 10502 2023-03-21 15:08:00          CL
# 48981 2023-12-21 09:41:00          CL
# 1526  2023-01-12 09:41:00          CL
# 19796 2023-05-24 09:02:00          CL
# 34057 2023-09-03 02:12:00           C
#
#                                                                                                                                                                                                                           Outage Comments
# 2279   ***Elevator OOS for Monthly PM ***\n\n\nWO  5407941\n1/18/23 @0040  Hrs (Rosario)  E&EM Daves  reports taking elevator OOS Monthly PM. \n\n E&EM Daves and E&EH Garita completed monthly preventative maintenance. BIS at 5:30am.
# 28051                                                                                                                                                                                   As per Liftnet Galaxy Client machine is running.
# 32192                                                                                                                                                                                                                                 NaN
# 23075                                                                                                                                                                                                                                 NaN
# 19294                                                                                                                                                                                                                                 NaN
# 10502                                                                                                                                                                                                                                 NaN
# 48981                                                                                                                                                                                                                                 NaN
# 1526                                                                                                                                                                                                                                  NaN
# 19796    ***This Elevator is out of service for Quarterly Maintenance ***\n\n\nE&EM Marshall and E&EH Alcaraz arrived at 7:50am. Here to perform quarterly PM.\n\nWO#6365319 Completed PM test ran and monitored machine BIS at 12:00pm.
# 34057                                                                                                                                                                                                                                 NaN

# %%
# create column `station MRN` to merge with `Station ID` to geolocate
df_ele['Station MRN'] = df_ele['Equipment Description'].str.extract(r'ELE: EL\d{2,3}\w? - (\d{2,3})\s-')

# %%
# check what the are the missing station MRN
# HOW DO I GET THESE!!!

df_ele[df_ele['Station MRN'].isna()].head(5)
# Out:
#      Out of Service Date Common Name  Outage  \
# 413  2023-01-04 07:23:00       EL740  792397
# 450  2023-01-04 11:45:00       EL741  792554
# 595  2023-01-05 11:20:00       EL739  792984
# 1348 2023-01-11 08:37:00       EL739  795146
# 1818 2023-01-14 09:10:00       EL156  796470
#
#                                       Equipment Description Executive Comment  \
# 413           ELE: EL740 - 73  - New Utrecht - Location TBD               NaN
# 450           ELE: EL741 - 73  - New Utrecht - Location TBD               NaN
# 595           ELE: EL739 - 73  - New Utrecht - Location TBD               NaN
# 1348          ELE: EL739 - 73  - New Utrecht - Location TBD               NaN
# 1818  ELE: EL156 - TBD - Dyckman St Quarters - Location TBD               NaN
#
#      Outage Code  Status                      External Source Note  \
# 413          INS  Closed                                       NaN
# 450          INS  Closed                                       NaN
# 595          INS  Closed                                       NaN
# 1348         ENV  Closed  Door Opening/ F. Door Open Limit failure
# 1818          PM  Closed                                       NaN
#
#      Reason Shown to Public Reason Shown to Public Description  \
# 413              INSPECTION                         Inspection
# 450              INSPECTION                         Inspection
# 595              INSPECTION                         Inspection
# 1348                 REPAIR                             Repair
# 1818            MAINTENANCE                        Maintenance
#
#      Estimated Return to Service Date Actual Return to Service Date  \
# 413               2023-01-04 16:00:00           2023-01-04 11:45:00
# 450               2023-01-04 17:00:00           2023-01-04 13:15:00
# 595               2023-01-05 17:00:00           2023-01-05 13:20:00
# 1348              2023-01-11 17:00:00           2023-01-11 11:30:00
# 1818              2023-01-14 18:00:00           2023-01-14 12:20:00
#
#                 Reference                      Source Service Code  \
# 413                   NaN                       Phone    EE-MANOUT
# 450                   NaN                       Phone    EE-MANOUT
# 595                   NaN                       Phone    EE-MANOUT
# 1348  ST230111.txt - 1256  External Monitoring System     EE-LNOUT
# 1818                  NaN                       Phone    EE-MANOUT
#
#             Date Created Status Code  \
# 413  2023-01-04 07:24:00          CL
# 450  2023-01-04 11:48:00          CL
# 595  2023-01-05 11:23:00          CL
# 1348 2023-01-11 08:44:00          CL
# 1818 2023-01-14 09:13:00          CL
#
#                                                                                                                                                                                                                                                            Outage Comments  \
# 413                 ***This elevator is out of service for CAT1 Inspection***\n\n\nE&EM Stewart and E&EH Crawford taking unit OOS for ASME CAT1 inspection. WO#5408464 (EAM) E&EH Crawford: ASME CAT1 inspection completed, machine passed inspection. Test ran RTS @1145
# 450   ***This unit was removed from service by E&E personnel to perform inspection***\nWO 5408465\nE&EM Stewart and E&EH Crawford here for ASME CAT1 inspection.\n E&EH Crawford report:  ASME CAT1 inspection completed, machine passed inspection. Test ran RTS @1315.
# 595        ***This unit was removed from service by E&E personnel to perform inspection***\nWO5408463\nE&EM Stewart and E&EH Crawford here for ASME CAT1 inspection.\n (EAM) E&EM Crawford: ASME CAT1 inspection completed, machine passed inspection. Test ran RTS @1320
# 1348                                                                                                                                                                                                                                                                   NaN
# 1818                                                                                                  ***This elevator is out of service for preventive maintenance***\n\n\n\n\n\nE&EMs Siu/Diaz taking unit OOS for bimonthly PM. WO#5407838 bimonthly PM. completed BIS
#
#      Station MRN
# 413          NaN
# 450          NaN
# 595          NaN
# 1348         NaN
# 1818         NaN

# %%
# convert string to float
df_ele['Station MRN'] = df_ele['Station MRN'].astype('Int64')

# drop all stations MRN > 523 and save to a new file
df_ele[df_ele['Station MRN'] <= 523].to_csv('2023_ele.csv', index=False)

# filter down to geolocatable columns
df_ele = df_ele[df_ele['Station MRN'] <= 523]
df_ele.sample(5)
# Out:
#       Out of Service Date Common Name  Outage  \
# 36263 2023-09-18 10:15:00       EL306  920993
# 31255 2023-08-12 20:40:00       EL391  906625
# 35547 2023-09-13 09:05:00       EL125  918759
# 33139 2023-08-26 12:36:00       EL710  911976
# 30349 2023-08-06 14:40:00       EL431  903888
#
#                                                     Equipment Description  \
# 36263  ELE: EL306 - 338 - Atlantic Av-Barclays Ctr - Manhattan Bound Plat
# 31255                          ELE: EL391 - 101 - Marcy Av - Outside Area
# 35547                                           ELE: EL125 - 392 - 125 St
# 33139                     ELE: EL710 - 414 - Bowling Green - Outside Area
# 30349                    ELE: EL431 - 254 - Jamaica-179 St - Outside Area
#
#                                                                                                         Executive Comment  \
# 36263  This elevator is out of service A&P for Contractors J-track TCE Forten AECOM Stantec to survey motor room and pit.
# 31255                                                                                                                 NaN
# 35547                                                          This elevator is out of service for Inspect UPS battery \n
# 33139                                                                                                                 NaN
# 30349                                                                                                                 NaN
#
#       Outage Code  Status External Source Note Reason Shown to Public  \
# 36263         APC  Closed                  NaN            PLANNEDWORK
# 31255         BRP  Closed                  NaN                 REPAIR
# 35547         MRP  Closed                  NaN            PLANNEDWORK
# 33139         ENV  Closed   DOOR CLOSE FAILURE                 REPAIR
# 30349         BRP  Closed                  NaN                 REPAIR
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 36263                       Planned Work              2023-09-18 15:00:00
# 31255                             Repair              2023-08-13 05:00:00
# 35547                       Planned Work              2023-09-13 15:00:00
# 33139                             Repair              2023-08-28 21:00:00
# 30349                             Repair              2023-08-06 22:00:00
#
#       Actual Return to Service Date            Reference  \
# 36263           2023-09-18 10:40:00                  NaN
# 31255           2023-08-13 01:35:00                  NaN
# 35547           2023-09-13 11:30:00                  NaN
# 33139           2023-08-26 19:30:00  ST230826.txt - 1968
# 30349           2023-08-06 16:30:00                  NaN
#
#                            Source Service Code        Date Created  \
# 36263                       Phone    EE-MANOUT 2023-09-18 10:20:00
# 31255                       Phone    EE-MANOUT 2023-08-12 20:42:00
# 35547                       Phone    EE-MANOUT 2023-09-13 09:07:00
# 33139  External Monitoring System     EE-LNOUT 2023-08-26 12:51:00
# 30349                       Phone    EE-MANOUT 2023-08-06 14:47:00
#
#       Status Code  \
# 36263          CL
# 31255          CL
# 35547          CL
# 33139          CL
# 30349          CL
#
#                                                                                                                                                                                                               Outage Comments  \
# 36263  WO # 7910161E&EM Mcgriff/Friday E&EH Lopez/Wright arrived for A&P at 0800. Contractors J-track TCE Forten AECOM Stantec on site to survey motor room and pit. OOS 1015 Contractors surveyed pit. Test ran. RTS @ 1040
# 31255                                                                                                                                                                                                                     NaN
# 35547                                                                                                                                                                                                                     NaN
# 33139                                                                                                                                                                                                                     NaN
# 30349                                                                                                                                                                                                                     NaN
#
#        Station MRN
# 36263          338
# 31255          101
# 35547          392
# 33139          414
# 30349          254

# %%
# load the geostation file
df_geostation = pd.read_csv('subway_stations.csv')

# merge the geostation file with the df_ele
df_ele_merged = df_ele.merge(df_geostation, left_on='Station MRN', right_on='Station ID')

pd.set_option('display.max_columns', 500)

# rename the columns
df_ele_merged = df_ele_merged.rename(columns={'GTFS Latitude': 'lat',  'GTFS Longitude': 'long'})

# %%
# check the merged file 
print(df_ele_merged.sample(5))

# save the merged file
df_ele_merged.to_csv('2023_ele_geocode.csv', index=False)
print(df_ele_merged.shape)

# WHY IS THERE MORE ROWS THAN THE ORIGINAL FILE??
# Out:
#       Out of Service Date Common Name  Outage  \
# 451   2023-01-09 23:50:00       EL192  794492
# 911   2023-01-18 09:22:00       EL738  797960
# 9112  2023-06-30 03:05:00       EL324  889893
# 6737  2023-05-16 13:03:00       EL720  864062
# 17497 2023-12-15 12:40:00       EL469  955821
#
#                               Equipment Description Executive Comment  \
# 451                       ELE: EL192 - 418 - 233 St               NaN
# 911    ELE: EL738 - 73 - New Utrecht - Location TBD               NaN
# 9112           ELE: EL324 - 410 - Canal St - Mezz A               NaN
# 6737     ELE: EL720 - 172 - Fulton St - Island Plat               NaN
# 17497                   ELE: EL469 - 281 - Court Sq               NaN
#
#       Outage Code     Status      External Source Note Reason Shown to Public  \
# 451            PM     Closed                       NaN            MAINTENANCE
# 911           APC     Closed                       NaN            PLANNEDWORK
# 9112          ENT     Closed               Power Fault           UNDERINVESTG
# 6737          VAN     Closed                       NaN           UNDERINVESTG
# 17497          FR  Cancelled  Rear safety edge failure           UNDERINVESTG
#
#       Reason Shown to Public Description Estimated Return to Service Date  \
# 451                          Maintenance              2023-01-10 08:00:00
# 911                         Planned Work              2023-01-18 16:00:00
# 9112                 Under Investigation              2023-06-30 12:00:00
# 6737                 Under Investigation              2023-05-16 22:00:00
# 17497                Under Investigation              2023-12-15 21:00:00
#
#       Actual Return to Service Date            Reference  \
# 451             2023-01-10 04:40:00                  NaN
# 911             2023-01-18 11:05:00                  NaN
# 9112            2023-06-30 04:40:00   ST230630.txt - 355
# 6737            2023-05-16 13:55:00                  NaN
# 17497                           NaT  ST231215.txt - 2460
#
#                            Source Service Code        Date Created  \
# 451                         Phone    EE-MANOUT 2023-01-09 23:51:00
# 911                         Phone    EE-MANOUT 2023-01-18 09:23:00
# 9112   External Monitoring System     EE-LNOUT 2023-06-30 03:18:00
# 6737                        Phone    EE-MANOUT 2023-05-16 13:06:00
# 17497  External Monitoring System     EE-LNOUT 2023-12-15 13:22:00
#
#       Status Code  \
# 451            CL
# 911            CL
# 9112           CL
# 6737           CL
# 17497           C
#
#                                                                                                                                                                                                                                                                                                                                                                                           Outage Comments  \
# 451                                                                                                                                                                ***This elevator is out of service for Quarterly PM***\nWO5408046   EAM OUT794492\n1/09/23 2350hrs {Jackson,R}E&EM's Greene & Dennison taking unit OOS for Quarterly PM E&EM's Greene & Dennison completed Quarterly PM. BIS @ 04:40.
# 911    ***This elevator is out of service to provide A&P to contractors (Mid American Elevator) to label the power unit***\nE&EM Urquiola and E&EH Garita arrived at 8:50am to provide A&P to contractors (Mid American Elevator) to label the power unit. Machine OOS @ 08:22. WO # 4675500 E&EM Urquiola and E&EH Garita provided A&P for contractors to label the power unit. Machine BIS at 11:05am.
# 9112                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 6737                                                                                                                                                                                                                                                                                                                                                                                                  NaN
# 17497                                                                                                                                                                                                                                                                                                                                                              As per Galaxy Client elevator running
#
#        Station MRN  Station ID  Complex ID GTFS Stop ID Division  \
# 451            418         418         418          205      IRT
# 911             73          73         615          N04      BMT
# 9112           410         410         623          639      IRT
# 6737           172         172         628          A38      IND
# 17497          281         281         606          G22      IND
#
#                           Line       Stop Name Borough Daytime Routes  \
# 451    Lenox - White Plains Rd          233 St      Bx            2 5
# 911                  Sea Beach  New Utrecht Av      Bk              N
# 9112              Lexington Av        Canal St       M              6
# 6737        8th Av - Fulton St       Fulton St       M            A C
# 17497                Crosstown        Court Sq       Q              G
#
#       Structure        lat       long North Direction Label  \
# 451    Elevated  40.893193 -73.857473    Wakefield - 241 St
# 911    Open Cut  40.624842 -73.996353             Manhattan
# 9112     Subway  40.718803 -74.000193    Uptown & The Bronx
# 6737     Subway  40.710197 -74.007691                Uptown
# 17497    Subway  40.746554 -73.943832                   NaN
#
#       South Direction Label  ADA ADA Notes                  Georeference
# 451               Manhattan    1       NaN  POINT (-73.857473 40.893193)
# 911            Coney Island    1       NaN  POINT (-73.996353 40.624842)
# 9112               Downtown    1       NaN  POINT (-74.000193 40.718803)
# 6737               Brooklyn    1       NaN  POINT (-74.007691 40.710197)
# 17497              Brooklyn    1       NaN  POINT (-73.943832 40.746554)
# (18208, 35)

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
import censusgeocode as cg
from concurrent.futures import ThreadPoolExecutor
from tqdm.notebook import tqdm

import requests_cache
cache = requests_cache.CachedSession("geocode_cache", backend="filesystem")

def geocode(lat, lng):
    try:
        url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
        params = {
            "x": lng,
            "y": lat,
            "benchmark": "Public_AR_Census2020",
            "vintage": "Census2020_Census2020",
            "format": "json"
        }
        response = cache.get(url, params=params)
        response.raise_for_status()
        data = response.json()
        census = data['result']['geographies']['Census Blocks'][0]
        return census
    except Exception as e:
        print(f"Error geocoding ({lat}, {lng}): {e}")
        return None

def bulk_geocode(latitudes, longitudes):
    """
    Geocode a list of latitudes and longitudes in parallel (for speed).
    """

    with ThreadPoolExecutor() as tpe:
        latitudes = df_ele_merged['lat']
        longitudes = df_ele_merged['long']
        mapped_results = tpe.map(geocode, latitudes, longitudes)
        data = list(tqdm(mapped_results, total=len(df_ele_merged)))

    return pd.DataFrame(data)

census_geos_df = bulk_geocode(df_ele_merged['lat'], df_ele_merged['long']) 
census_geos_df.head()
# Out:
#   0%|          | 0/18208 [00:00<?, ?it/s]
#   SUFFIX  POP100            GEOID      CENTLAT BLOCK  AREAWATER STATE  \
# 0            610  360470296002002  +40.6008553  2002          0    36
# 1              0  360050403021003  +40.8669415  1003          0    36
# 2            593  360610034004000  +40.7305461  4000          0    36
# 3              0  360810208001000  +40.6998869  1000          0    36
# 4              0  360810033011019  +40.7492525  1019          0    36
#
#   BASENAME              OID LSADC     INTPTLAT FUNCSTAT        NAME  OBJECTID  \
# 0     2002  210701004650915    BK  +40.6008553        S  Block 2002   4615836
# 1     1003  210701006017414    BK  +40.8669415        S  Block 1003   1475683
# 2     4000  210701008621623    BK  +40.7305461        S  Block 4000   2844262
# 3     1000  210701006104178    BK  +40.6998869        S  Block 1000   1848413
# 4     1019  210701006117049    BK  +40.7492525        S  Block 1019   1404062
#
#     TRACT       CENTLON BLKGRP  AREALAND  HU100      INTPTLON  MTFCC LWBLKTYP  \
# 0  029600  -073.9943207      2     20213    242  -073.9943207  G5040        L
# 1  040302  -073.8935996      1      3799      0  -073.8935996  G5040        L
# 2  003400  -073.9817046      4     19330    415  -073.9817046  G5040        L
# 3  020800  -073.8089158      1     13876      0  -073.8089158  G5040        L
# 4  003301  -073.9374018      1      3969      0  -073.9374018  G5040        L
#
#   UR COUNTY
# 0  U    047
# 1  U    005
# 2  U    061
# 3  U    081
# 4  U    081

# %%
to_keep = ['GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK']
census_geos_df = census_geos_df[to_keep]
census_geos_df
# Out:
#                  GEOID STATE COUNTY   TRACT BLOCK
# 0      360470296002002    36    047  029600  2002
# 1      360050403021003    36    005  040302  1003
# 2      360610034004000    36    061  003400  4000
# 3      360810208001000    36    081  020800  1000
# 4      360810033011019    36    081  003301  1019
# ...                ...   ...    ...     ...   ...
# 18203  360610137003000    36    061  013700  3000
# 18204  360610137003000    36    061  013700  3000
# 18205  360610137003000    36    061  013700  3000
# 18206  360050224031001    36    005  022403  1001
# 18207  360810216021008    36    081  021602  1008
#
# [18208 rows x 5 columns]

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
df_with_geos = pd.concat(
    [ 
        df.reset_index(drop=True),
        census_geos_df.reset_index(drop=True)
    ], 
    axis=1)

df_with_geos.head()
# Out:
#   Out of Service Date Common Name  Outage  \
# 0 2023-01-01 00:00:00       ES429  791240
# 1 2023-01-01 00:03:00       ES627  791231
# 2 2023-01-01 00:14:00       ES369  791239
# 3 2023-01-01 00:14:00       EL376  791238
# 4 2023-01-01 00:44:00       ES374  791251
#
#                             Equipment Description Executive Comment  \
# 0      ESC: ES429 - 280 - Jamaica Van Wyck - Plat               NaN
# 1  ESC: ES627 - 471 - 34 St-Hudson Yards - Mezz A               NaN
# 2   ESC: ES369 - 330 - South Ferry - Outside Area               NaN
# 3      ELE: EL376 - 068 - Bay Pkwy - Outside Area               NaN
# 4    ESC: ES374 - 330 - South Ferry - Island Plat               NaN
#
#   Outage Code  Status External Source Note Reason Shown to Public  \
# 0          FR  Closed          Not Running           UNDERINVESTG
# 1         CLN  Closed                  NaN               CLEANING
# 2         CLN  Closed                  NaN               CLEANING
# 3          PM  Closed                  NaN            MAINTENANCE
# 4         BRP  Closed              Stopped           UNDERINVESTG
#
#   Reason Shown to Public Description Estimated Return to Service Date  \
# 0                Under Investigation              2023-01-01 09:00:00
# 1                           Cleaning              2023-01-01 07:00:00
# 2                           Cleaning              2023-01-01 09:00:00
# 3                        Maintenance              2023-01-01 07:00:00
# 4                Under Investigation              2023-01-01 09:00:00
#
#   Actual Return to Service Date          Reference  \
# 0           2023-01-01 01:20:00  ST230101.txt - 17
# 1           2023-01-01 00:11:00                NaN
# 2           2023-01-01 00:53:00                NaN
# 3           2023-01-01 05:30:00                NaN
# 4           2023-01-01 01:30:00  ST230101.txt - 79
#
#                        Source Service Code        Date Created Status Code  \
# 0  External Monitoring System     EE-LNOUT 2023-01-01 00:17:00          CL
# 1                       Phone    EE-MANOUT 2023-01-01 00:03:00          CL
# 2                       Phone    EE-MANOUT 2023-01-01 00:15:00          CL
# 3                       Phone    EE-MANOUT 2023-01-01 00:14:00          CL
# 4  External Monitoring System     EE-LNOUT 2023-01-01 00:51:00          CL
#
#                                                                                                                                                               Outage Comments  \
# 0                                                                                                                                                                         NaN
# 1  ***This Escalator is out of service for Cleaning***\n\n\nCTA  Lindsay #525064 Reports stopped machine for Cleaning.  CTA  Lindsay #525064 Reports complete cleaning RTS.
# 2                                                        \n\n*** This escalator is out of service for Routine Cleaning *** CTA Jacob #429032 Reports complete cleaning RTS.
# 3          ***This Elevator is out of service for Maintenance***\n\n\nE&EM R.Brown and E&Eh K.Singh arrived for maintenance at 00:05. WO #5407916 PM Completed and RTS @5.30
# 4                                                                                                                                                                         NaN
#
#              GEOID STATE COUNTY   TRACT BLOCK
# 0  360470296002002    36    047  029600  2002
# 1  360050403021003    36    005  040302  1003
# 2  360610034004000    36    061  003400  4000
# 3  360810208001000    36    081  020800  1000
# 4  360810033011019    36    081  003301  1019

# %%
df_with_geos.to_csv('df_censusgeo.csv', index=False)
